# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Academic-Performance-Dataset.csv")

# %%
data.head()
# Out:
#    Rollno     Name Gender Branch  Attendence  Phy_marks  Che_marks  EM1_marks  \
# 0       1   Shivam      M   Comp          72       62.0       98.0       63.0
# 1       2  Reyansh      M     IT          58       62.0       83.0       83.0
# 2       3    Aarav      M     IT          57      -20.0      100.0        NaN
# 3       4   Atharv      M     IT          60       89.0       83.0       70.0
# 4       5   Vivaan      M   Comp          85       90.0        NaN       78.0
#
#    PPS_marks  SME_marks  Total Marks  Percentage
# 0       89.0         36          368        73.6
# 1       88.0         34          350        70.0
# 2       56.0         36          192        38.4
# 3       33.0         23          298        59.6
# 4       23.0         56          247        49.4

# %%
data
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1     Shivam      M   Comp          72       62.0       98.0
# 1        2    Reyansh      M     IT          58       62.0       83.0
# 2        3      Aarav      M     IT          57      -20.0      100.0
# 3        4     Atharv      M     IT          60       89.0       83.0
# 4        5     Vivaan      M   Comp          85       90.0        NaN
# 5        6      Advik      M   ENTC          94       99.0       84.0
# 6        7       Ansh      M   ENTC          98       88.0       95.0
# 7        8     Ishaan      M   ENTC          75       66.0       51.0
# 8        9      Dhruv      M   ENTC          63        NaN        NaN
# 9       10  Siddharth      M   ENTC          96       67.0       78.0
# 10      11     Vihaan      M   ENTC          82       54.0       70.0
# 11      12        NaN      M     IT          75       64.0       67.0
# ...

# %%
data.isnull()
# Out:
#     Rollno   Name  Gender  Branch  Attendence  Phy_marks  Che_marks  \
# 0    False  False   False   False       False      False      False
# 1    False  False   False   False       False      False      False
# 2    False  False   False   False       False      False      False
# 3    False  False   False   False       False      False      False
# 4    False  False   False   False       False      False       True
# 5    False  False   False   False       False      False      False
# 6    False  False   False   False       False      False      False
# 7    False  False   False   False       False      False      False
# 8    False  False   False   False       False       True       True
# 9    False  False   False   False       False      False      False
# 10   False  False   False   False       False      False      False
# 11   False   True   False   False       False      False      False
# 12   False  False   False   False       False      False      False
# ...

# %%
series = pd.isnull(data["Phy_marks"])

# %%
data[series]
# Out:
#    Rollno   Name Gender Branch  Attendence  Phy_marks  Che_marks  EM1_marks  \
# 8       9  Dhruv      M   ENTC          63        NaN        NaN       97.0
#
#    PPS_marks  SME_marks  Total Marks  Percentage
# 8       56.0         55          208        41.6

# %%
data.notnull()
# Out:
#     Rollno   Name  Gender  Branch  Attendence  Phy_marks  Che_marks  \
# 0     True   True    True    True        True       True       True
# 1     True   True    True    True        True       True       True
# 2     True   True    True    True        True       True       True
# 3     True   True    True    True        True       True       True
# 4     True   True    True    True        True       True      False
# 5     True   True    True    True        True       True       True
# 6     True   True    True    True        True       True       True
# 7     True   True    True    True        True       True       True
# 8     True   True    True    True        True      False      False
# 9     True   True    True    True        True       True       True
# 10    True   True    True    True        True       True       True
# 11    True  False    True    True        True       True       True
# 12    True   True    True    True        True       True       True
# ...

# %%
series1 = pd.notnull(data['Phy_marks'])

# %%
data[series1]
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1     Shivam      M   Comp          72       62.0       98.0
# 1        2    Reyansh      M     IT          58       62.0       83.0
# 2        3      Aarav      M     IT          57      -20.0      100.0
# 3        4     Atharv      M     IT          60       89.0       83.0
# 4        5     Vivaan      M   Comp          85       90.0        NaN
# 5        6      Advik      M   ENTC          94       99.0       84.0
# 6        7       Ansh      M   ENTC          98       88.0       95.0
# 7        8     Ishaan      M   ENTC          75       66.0       51.0
# 9       10  Siddharth      M   ENTC          96       67.0       78.0
# 10      11     Vihaan      M   ENTC          82       54.0       70.0
# 11      12        NaN      M     IT          75       64.0       67.0
# 12      13     Aarush      M     IT          67       56.0       81.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['Gender'] = le.fit_transform(data['Gender'])
newdata = data

# %%
data
# Out:
#     Rollno       Name  Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1     Shivam       1   Comp          72       62.0       98.0
# 1        2    Reyansh       1     IT          58       62.0       83.0
# 2        3      Aarav       1     IT          57      -20.0      100.0
# 3        4     Atharv       1     IT          60       89.0       83.0
# 4        5     Vivaan       1   Comp          85       90.0        NaN
# 5        6      Advik       1   ENTC          94       99.0       84.0
# 6        7       Ansh       1   ENTC          98       88.0       95.0
# 7        8     Ishaan       1   ENTC          75       66.0       51.0
# 8        9      Dhruv       1   ENTC          63        NaN        NaN
# 9       10  Siddharth       1   ENTC          96       67.0       78.0
# 10      11     Vihaan       1   ENTC          82       54.0       70.0
# 11      12        NaN       1     IT          75       64.0       67.0
# ...

# %%
newdata
# Out:
#     Rollno       Name  Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1     Shivam       1   Comp          72       62.0       98.0
# 1        2    Reyansh       1     IT          58       62.0       83.0
# 2        3      Aarav       1     IT          57      -20.0      100.0
# 3        4     Atharv       1     IT          60       89.0       83.0
# 4        5     Vivaan       1   Comp          85       90.0        NaN
# 5        6      Advik       1   ENTC          94       99.0       84.0
# 6        7       Ansh       1   ENTC          98       88.0       95.0
# 7        8     Ishaan       1   ENTC          75       66.0       51.0
# 8        9      Dhruv       1   ENTC          63        NaN        NaN
# 9       10  Siddharth       1   ENTC          96       67.0       78.0
# 10      11     Vihaan       1   ENTC          82       54.0       70.0
# 11      12        NaN       1     IT          75       64.0       67.0
# ...

# %%
missing_values = ["Na", "na"]
data = pd.read_csv("Academic-Performance-Dataset.csv", na_values = missing_values)

# %%
data
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1     Shivam      M   Comp          72       62.0       98.0
# 1        2    Reyansh      M     IT          58       62.0       83.0
# 2        3      Aarav      M     IT          57      -20.0      100.0
# 3        4     Atharv      M     IT          60       89.0       83.0
# 4        5     Vivaan      M   Comp          85       90.0        NaN
# 5        6      Advik      M   ENTC          94       99.0       84.0
# 6        7       Ansh      M   ENTC          98       88.0       95.0
# 7        8     Ishaan      M   ENTC          75       66.0       51.0
# 8        9      Dhruv      M   ENTC          63        NaN        NaN
# 9       10  Siddharth      M   ENTC          96       67.0       78.0
# 10      11     Vihaan      M   ENTC          82       54.0       70.0
# 11      12        NaN      M     IT          75       64.0       67.0
# ...

# %%
m_v = data['Phy_marks'].mean()
data['Phy_marks'].fillna(value = m_v, inplace = True)

# %%
data
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1     Shivam      M   Comp          72  62.000000       98.0
# 1        2    Reyansh      M     IT          58  62.000000       83.0
# 2        3      Aarav      M     IT          57 -20.000000      100.0
# 3        4     Atharv      M     IT          60  89.000000       83.0
# 4        5     Vivaan      M   Comp          85  90.000000        NaN
# 5        6      Advik      M   ENTC          94  99.000000       84.0
# 6        7       Ansh      M   ENTC          98  88.000000       95.0
# 7        8     Ishaan      M   ENTC          75  66.000000       51.0
# 8        9      Dhruv      M   ENTC          63  63.421053        NaN
# 9       10  Siddharth      M   ENTC          96  67.000000       78.0
# 10      11     Vihaan      M   ENTC          82  54.000000       70.0
# 11      12        NaN      M     IT          75  64.000000       67.0
# ...

# %%
nsp = data
nsp.fillna(0)
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1     Shivam      M   Comp          72  62.000000       98.0
# 1        2    Reyansh      M     IT          58  62.000000       83.0
# 2        3      Aarav      M     IT          57 -20.000000      100.0
# 3        4     Atharv      M     IT          60  89.000000       83.0
# 4        5     Vivaan      M   Comp          85  90.000000        0.0
# 5        6      Advik      M   ENTC          94  99.000000       84.0
# 6        7       Ansh      M   ENTC          98  88.000000       95.0
# 7        8     Ishaan      M   ENTC          75  66.000000       51.0
# 8        9      Dhruv      M   ENTC          63  63.421053        0.0
# 9       10  Siddharth      M   ENTC          96  67.000000       78.0
# 10      11     Vihaan      M   ENTC          82  54.000000       70.0
# 11      12          0      M     IT          75  64.000000       67.0
# ...

# %%
nsp.replace(to_replace = np.nan, value = -99)
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1     Shivam      M   Comp          72  62.000000       98.0
# 1        2    Reyansh      M     IT          58  62.000000       83.0
# 2        3      Aarav      M     IT          57 -20.000000      100.0
# 3        4     Atharv      M     IT          60  89.000000       83.0
# 4        5     Vivaan      M   Comp          85  90.000000      -99.0
# 5        6      Advik      M   ENTC          94  99.000000       84.0
# 6        7       Ansh      M   ENTC          98  88.000000       95.0
# 7        8     Ishaan      M   ENTC          75  66.000000       51.0
# 8        9      Dhruv      M   ENTC          63  63.421053      -99.0
# 9       10  Siddharth      M   ENTC          96  67.000000       78.0
# 10      11     Vihaan      M   ENTC          82  54.000000       70.0
# 11      12        -99      M     IT          75  64.000000       67.0
# ...

# %%
nsp.dropna()
# Out:
#     Rollno     Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1   Shivam      M   Comp          72       62.0       98.0
# 1        2  Reyansh      M     IT          58       62.0       83.0
# 3        4   Atharv      M     IT          60       89.0       83.0
# 5        6    Advik      M   ENTC          94       99.0       84.0
# 6        7     Ansh      M   ENTC          98       88.0       95.0
# 7        8   Ishaan      M   ENTC          75       66.0       51.0
# 10      11   Vihaan      M   ENTC          82       54.0       70.0
# 13      14      Leo      M     IT          98      -34.0       70.0
# 14      15   Maryam      F     IT          64       87.0       60.0
# 15      16   Saanvi      F   Comp          66       90.0       95.0
# 17      18    Inaya      F   Comp          74       67.0       93.0
# 18      19    Aarya      F   Comp          72       88.0       84.0
#
#     EM1_marks  PPS_marks  SME_marks  Total Marks  Percentage
# ...

# %%
nsp.dropna(how = 'all')
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1     Shivam      M   Comp          72  62.000000       98.0
# 1        2    Reyansh      M     IT          58  62.000000       83.0
# 2        3      Aarav      M     IT          57 -20.000000      100.0
# 3        4     Atharv      M     IT          60  89.000000       83.0
# 4        5     Vivaan      M   Comp          85  90.000000        NaN
# 5        6      Advik      M   ENTC          94  99.000000       84.0
# 6        7       Ansh      M   ENTC          98  88.000000       95.0
# 7        8     Ishaan      M   ENTC          75  66.000000       51.0
# 8        9      Dhruv      M   ENTC          63  63.421053        NaN
# 9       10  Siddharth      M   ENTC          96  67.000000       78.0
# 10      11     Vihaan      M   ENTC          82  54.000000       70.0
# 11      12        NaN      M     IT          75  64.000000       67.0
# ...

# %%
nsp.dropna(axis = 1)
# Out:
#     Rollno Gender Branch  Attendence  Phy_marks  SME_marks  Total Marks  \
# 0        1      M   Comp          72  62.000000         36          368
# 1        2      M     IT          58  62.000000         34          350
# 2        3      M     IT          57 -20.000000         36          192
# 3        4      M     IT          60  89.000000         23          298
# 4        5      M   Comp          85  90.000000         56          247
# 5        6      M   ENTC          94  99.000000         99          438
# 6        7      M   ENTC          98  88.000000         78          420
# 7        8      M   ENTC          75  66.000000         76          192
# 8        9      M   ENTC          63  63.421053         55          208
# 9       10      M   ENTC          96  67.000000         98          338
# 10      11      M   ENTC          82  54.000000         56          323
# 11      12      M     IT          75  64.000000         87          355
# ...

# %%
new_data = nsp.dropna(axis = 0, how = 'any')

# %%
new_data
# Out:
#     Rollno     Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1   Shivam      M   Comp          72       62.0       98.0
# 1        2  Reyansh      M     IT          58       62.0       83.0
# 3        4   Atharv      M     IT          60       89.0       83.0
# 5        6    Advik      M   ENTC          94       99.0       84.0
# 6        7     Ansh      M   ENTC          98       88.0       95.0
# 7        8   Ishaan      M   ENTC          75       66.0       51.0
# 10      11   Vihaan      M   ENTC          82       54.0       70.0
# 13      14      Leo      M     IT          98      -34.0       70.0
# 14      15   Maryam      F     IT          64       87.0       60.0
# 15      16   Saanvi      F   Comp          66       90.0       95.0
# 17      18    Inaya      F   Comp          74       67.0       93.0
# 18      19    Aarya      F   Comp          72       88.0       84.0
#
#     EM1_marks  PPS_marks  SME_marks  Total Marks  Percentage
# ...

# %%
col = ['Phy_marks','Che_marks','EM1_marks','PPS_marks','SME_marks']
data.boxplot(col)
# Out:
# <AxesSubplot:>

# %%
print(np.where(data['Phy_marks']>90))
# Out:
# (array([5], dtype=int64),)

# %%
print(np.where(data['PPS_marks']<60))
# Out:
# (array([ 2,  3,  4,  5,  7,  8, 10], dtype=int64),)

# %%
print(np.where(data['Che_marks']<60))
# Out:
# (array([7], dtype=int64),)

# %%
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(data['PPS_marks'],data['Percentage'])

# %%
plt.show()

# %%
print(np.where(data['Phy_marks']>90) & (data['PPS_marks']>75))
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13     True
# 14    False
# 15     True
# 16     True
# 17     True
# 18     True
# 19    False
# Name: PPS_marks, dtype: bool

# %%
from scipy import stats

# %%
z = np.abs(stats.zscore(data['Phy_marks']))
print(z)
# Out:
# 0     0.042871
# 1     0.042871
# 2     2.516691
# 3     0.771679
# 4     0.801848
# 5     1.073365
# 6     0.741511
# 7     0.077803
# 8     0.000000
# 9     0.107972
# 10    0.284219
# 11    0.017466
# 12    0.223882
# 13    2.939050
# 14    0.711342
# 15    0.801848
# 16    0.284219
# 17    0.107972
# 18    0.741511
# 19    0.379488
# Name: Phy_marks, dtype: float64

# %%
threshold = 0.18

# %%
sample_outliers = np.where(z < threshold)
sample_outliers
# Out:
# (array([ 0,  1,  7,  8,  9, 11, 17], dtype=int64),)

# %%
sorted_rscore = sorted(data['Phy_marks'])

# %%
sorted_rscore
# Out:
# [-34.0,
#  -20.0,
#  54.0,
#  54.0,
#  56.0,
#  62.0,
#  62.0,
#  63.421052631578945,
#  64.0,
#  66.0,
#  67.0,
#  67.0,
#  76.0,
#  87.0,
#  88.0,
#  88.0,
#  89.0,
#  90.0,
#  90.0,
#  99.0]

# %%
# Follow
